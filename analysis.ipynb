# %%
print("Notebook çalışıyor 🚀")
# Out:
# Notebook çalışıyor 🚀

# %%
git status
git add analysis.ipynb
git commit -m "Fix notebook file"
git push
# Out:
#   Cell In[2], line 1
#     git status
#         ^
# SyntaxError: invalid syntax
